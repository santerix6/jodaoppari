# %% [markdown]
# # Oppimispäiväkirja JODA viikko 1:
#
#  Kurssi alkoi todella mielenkiintoisella luennolla, jossa olin paikanpäällä livenä zoomin välityksellä. Kurssin aihe on todella mielenkiintoinen ja juuri semmoista asiaa, jota halusinkin informaatioanalytiikan aihekokonaisuudelta. Ensimmäinen luento sujui melko perinteisissä ensimmäisen luennon merkeissä, kun käytiin läpi kurssin suorittamiseen liittyvät asiat, sekä hieman perusasioita datatieteestä. Kurssin vetäjä myös esitteli itsensä ja kurssiassistentit. Kurssin suorittaminen vaikuttaa melko suoraviivaiselta, sekä järkevältä ja harjoitustyö vaikuttaa hyvältä. Myös oppimispäiväkirja on hyvä tapa tehdä töitä koko kurssin ajan, eikä vain lopussa luettaessa tenttiin.
#  Luennolla ensimmäinen mielenkiintoinen pointti oli datatieteen määritelmää ja historiaa. Datatieteen pohja on tilastotieteessä. Ja sitä on perinteisesti tehty R kielellä. Nykyään kuitenkin Python alkaa olemaan yleisin kieli, jolla datatiedettä tehdään. Datan määrä nykyaikana on myös järjettömän suuri. Luennolla esitettiin, että vuonna 2025 dataa on maailmassa 163 Zetabittiä, joka on käsittämätön määrä. Datan määrä itsessään ei kuitenkaan luo arvoa, vaan datasta pitää löytää relevantit osat, josta voidaan löytää järkevää informaatiota ja tietämystä. (Tämä on aikalailla tietojohtamisen ydin)
#  Kurssilla käytetään tätä Jupyter työkirjaa oppimispäiväkirjan tekemiseen. Tämä sovellus vaikutaa erinomaiselta työkalulta datatieteeseen, kuten luennoitsijakin sanoi. Tällä sovelluksella pystyy helposti yhdistämään kirjoitettua koodia, sekä normaalia tekstiä, linkkejä ja kuvia.

# %%
print("hello World")
for x in range(1,10):
    print(x)
# Out:
# hello World
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# Yllä näkyy yksinkertainen koodin pätkä Jupyterissä. Jupyterillä pystyy siis käytännössä tekemään mitä tahansa python koodia. Ensimmäisellä luennolla käytiinkin läpi pandasin perusteita, sekä käytiin läpi esimerkki dataa, jota löytyy valmiista python kirjastoista. Tämä onkin tämän viikon koodin pätkäni.

# %%
#!pip install seaborn

# %%
import pandas as pd
import seaborn as sns
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Ylempi koodin pätkä on löydetty stackoverflowsta osoitteesta: https://stackoverflow.com/questions/28417293/sample-datasets-in-pandas siinä ideana on importata pandas ja sen lisäksi esimerkki dataa. Siinä nähdään esimerkki dataa dataframe muodossa.

# %% [markdown]
# ## Oivallukset
# 1. Ensimmäinen oivallukseni ensimäilessä luennolla oli, kuinka moniulotteista datatieteilijän työ on. Toinen oivallus oli se, kuinka pitkälle python kirjastot on datatieteeseen liityen on tehty.
# 2. Nykyään ei tarvitse hirveästi tehdä itse, kun lähes kaikki on tehty valmiiksi.
# 3. Mooren lain vaikutus dataan ja sen käsittelemiseen. Toisaalta puhetta on ollut Mooren lain hidastumisesta, miten tämä vaikutaa datatieteeseen?
# 4. Datatieteilijän pitää osata paljon eri tekniikoita.

# %% [markdown]
# Ensimmäinen luento oli mielestäni kaiken kaikkiaan todella hyvä ja kiinnostava, eikä minulta löydy hirveästi parannettavaa.
