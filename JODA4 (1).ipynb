# %% [markdown]
# # Joda oppimispäiväkirja 4
#
# En päässyt viikolla neljä luennolle paikan päälle, joten tämä päiväkirja on tehty pitkälti luentomateriaalien perusteella. Neljännen luennon aiheena oli kurssin harjoitustyö ja sen ohjeistus. Tämän takia tämä oppimispäiväkirja on hieman lyhyempi, sillä varsinaista uuden oppimista ei ollu niin paljoa. Luennon alussa käytiin läpi erilaisia analyysiprosessja, joita voisi käyttää harjoitustyössä. CRISP-DM-malli on varmaan järkevin, sillä sitä käytetään ilmeisesti myös paljon työelämässä. Myös harjoitystyössä on hyvä pitää mielessä, että tärkeintä datatiedeprojekteissa on liiketoimintaongelman ratkaiseminen, eikä data itseisarvona. Oli harmillista, että en päässyt mukaan luennolle, sillä siellä oli ilmeisesti käyty hyvää keskustelua Airbnbn liiketoiminnasta. Tästä olisi ollut hyötyä harjoitustyössä, sillä Airbnb data on helpoin ja tuetuin datasetti harjoitustyötä tehdessä. En ole vielä varma käytänkö Airbnb dataa omassa harjoitustyössäni. Data on sinänsä mielenkiintoista ja siihen saisi helpoiten tukea, mutta toisaalta haluaisin ehkä käyttää toisenlaista dataa, joka kiinnostaisi itseäni vielä enemmän. Susara van den Heeverin analytiikan onnistumisen mittaamisen mittarit olivat mielenkiintoiset ja varmasti järkevät.
# Harjoitystyö koostuu tiivistetysti seuraavasti.
# 1. Valitaan mielenkiintoinen ongelma, joka halutaan ratkaista.
# 2. Hankitaan dataa, jota tutkitaan
# 3. Datan putsaaminen, tarkastelu ja käsittely
# 4. Aineiston rikastaminen ja muuttaminen muotoon, jossa siitä on hyötyä ongelman ratkaisemisessa.
# 5. Datan visualisointi.
# 6. Datan mallintaminen mahdollisesti koneoppimisen keinoin
# 7. Iterointi. Data-analytiikka ei onnistu aina ensimmäisellä yrityksellä.
# Tämän viikon koodi pätkä on API kutsu, joka tehdään Helsingin Sanomien päivittämään Apiin, jossa on Suomessa koronavirus rokotettujen määriä.

# %%
import requests
#tässä koodin pätkässä haetaan tieto Suomessa rokotetuiden kokonaismäärästä minäkin päivä.
res = requests.get("https://w3qa5ydb4l.execute-api.eu-west-1.amazonaws.com/prod/finnishVaccinationData")
#print(res.json())
total_vac = 0
for x in res.json():
    print(x["area"],x["date"],x["shots"])
# Out:
# TYKS 2020-12-26T12:00:00.000Z 0
# HYKS 2020-12-26T12:00:00.000Z 0
# TAYS 2020-12-26T12:00:00.000Z 0
# KYS 2020-12-26T12:00:00.000Z 0
# OYS 2020-12-26T12:00:00.000Z 0
# Other areas 2020-12-26T12:00:00.000Z 0
# Finland 2020-12-26T12:00:00.000Z 0
# TYKS 2020-12-27T12:00:00.000Z 0
# HYKS 2020-12-27T12:00:00.000Z 24
# TAYS 2020-12-27T12:00:00.000Z 0
# KYS 2020-12-27T12:00:00.000Z 0
# OYS 2020-12-27T12:00:00.000Z 0
# Other areas 2020-12-27T12:00:00.000Z 0
# Finland 2020-12-27T12:00:00.000Z 24
# TYKS 2020-12-28T12:00:00.000Z 124
# HYKS 2020-12-28T12:00:00.000Z 470
# TAYS 2020-12-28T12:00:00.000Z 70
# KYS 2020-12-28T12:00:00.000Z 12
# OYS 2020-12-28T12:00:00.000Z 268
# Other areas 2020-12-28T12:00:00.000Z 0
# Finland 2020-12-28T12:00:00.000Z 944
# TYKS 2020-12-29T12:00:00.000Z 301
# HYKS 2020-12-29T12:00:00.000Z 1252
# TAYS 2020-12-29T12:00:00.000Z 192
# KYS 2020-12-29T12:00:00.000Z 34
# OYS 2020-12-29T12:00:00.000Z 792
# Other areas 2020-12-29T12:00:00.000Z 4
# ...
